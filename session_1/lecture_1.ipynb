# %% [markdown]
# # Notebook contents:
#
# This notebook contains a lecture. The code for generating plots are found at the of the notebook. Links below.
#
# - [presentation](#Session-1b:)
# - [code for plots](#Code-for-plots)

# %% [markdown]
# # Recording of class
# Background: people join from Americas/East Asia
#
# Solution: recording of class
# - Will be put on secret youtube links - not searchable
# - Delete mid June
#
# Consent: via poll

# %% [markdown]
# # Session 1:
# ## Machine learning introduction
#
# *Andreas Bjerre-Nielsen*

# %% [markdown]
# ## Agenda this class
#
# 1. [General introduction](#General-introduction)
# 1. [Introduction to Machine Learning](#Introduction-to-Machine-Learning)
# 1. [The fundamental modeling problem](#The-fundamental-modeling-problem)
# 1. [Modelling data: overfitting vs underfitting](#Modelling-data:-overfitting-vs-underfitting)
# 1. [Machine learning overview](#Machine-learning-overview)
# 1. [Supervised machine learning](#Supervised-machine-learning)
#     1. [the perceptron](#The-perceptron-model)
#     1. [simple model validation](#Simple-model-validation)
#     1. [beyond the perceptron](#Beyond-the-perceptron)
#     1. [linear regression models](#Linear-regression-models)

# %% [markdown]
# # General introduction
#
# ### Course and background

# %% [markdown]
# ## About Andreas
#
# - Assistant professor at University of Copenhagen
# - Research:
#     - Work on relevant pure prediction problems
#     - Intersection with economics
#       - School choice
#       - Tax audits
# - Teaching:
#     - Developed courses in data science/economics;
#     - Head of studies for degree in Social Data Science

# %% [markdown]
# ## About you
#
# - Mostly from econ (90%> of responses)
# - Experience of median participant:
#   - Strong-intermediate econometrics knowledge
#   - Low-medium Python skills
#   - Little-no machine learning experience

# %% [markdown]
# ## Why we are here
#
# Solve major problems
# 1. Regulate increasingly tech-based econony, and emerging fintech
#   1. Should we place limits on how to use algorithms for decision?
# 1. Leverage new tools for better policies
#   1. Better purely predictive models
#     - E.g. for forecasting, lending, fraud, academic aptitude
#   1. Leverage large unstructured data
#     - Historic archives, novel data in image/text
#   1. Improve economtric models by combining with machine learning
#     - Which sub-groups to treat?
#
# Relevance: within and outside academic - career hedge

# %% [markdown]
# ## Expected learning outcomes
#
# We will use your Python and econometrics competencies to learn:
# - Solid foundation in machine learning (ML)
#   - Knowledge of how advantages and disadvantages of ML estimators
#   - Ability to apply models on data
# - Overlap with economics
#   - Applications in estimation
#   - Algorithms and policy
#
# Lectures + coding exercises (with solutions)

# %% [markdown]
# ## Software check-up - poll
#
# Are you up to speed?

# %% [markdown]
# - I will stay around after the teaching for 30 mins. to help you install software
# - If problems persist we will find solutions

# %% [markdown]
# ## Learning approach
#
# Lectures are live, but plan to be recorded
#
# Coding is self-taught:
# - exercises in one notebook, solutions in other

# %% [markdown]
# ## Learning advice
#
# There is a lot of teaching material, perhaps too much
# 1. If you have not prepared with Python
#   - Do not freak out! see below
# 2. Getting the most out of the course by:
#   - Focus on knowledge, understanding and big picture
#   - Implementation details, Python and coding skills can be acquired afterwards!

# %% [markdown]
# ## Exam
#
# Why are we having an exam?
#
# - Practice makes perfect: like exercises, meant as feedback
# - Focus on research proposal - how can you use tools for your research

# %% [markdown]
# ## Course outline
#
# - Machine learning essentials
#   - Prediction models: how, why and pitfalls [session 1-4]
#   - Models for unstructured data (clustering etc.) [session 4]
# - Embedding into economic theory and econometric methods
#   - Algorithms and policy [session 4]
#   - Hybrid: machine learning and econometrics [session 5-6]
# - Presentations of preliminary proposals [session 7]

# %% [markdown]
# # Introduction to Machine Learning

# %% [markdown]
# ## Function fitting
# *What does (supervised) machine learning do?*

# %% [markdown]
# Suppose we have some data $y$ we want to model/predict from input $x$.
#
# The aim is to find a function $f$ such that the distance between actual values $y$ and predicted values $f(x)$ are minimized.

# %% [markdown]
#  ## Different purposes with models
#
#
# Models are pursued with differens aims. Suppose we have a linear model, $y=x\beta+\epsilon$.
#
# - Social science:
#     - They teach us something about the world.
#     - We want to estimate $\hat{\beta}$ and its distribution, preferable as causal estimate.
# - Data science:
#     - To make optimal future decisions and precise predictions, i.e. $\hat{y}$.

# %% [markdown]
# ## Examples of modelling

# %% [markdown]
# - Linear form: $y=x^T\beta$.
# - Non-linear form: $y=g(x^T\beta)$, e.g. $g$ is a logistic function, interaction of all variables.
#
# where $x^T\beta=\beta_0+x_1\beta_1+x_2\beta_2+...+x_n\beta_n$ (vector dot product)
#
# where $x,\beta$ a vector is 1-dimensional array of numbers, e.g.
# \begin{align}\boldsymbol{x}=[x_0,x_1,x_2,..,x_n]\end{align}

# %% [markdown]
# ## Limits to linear models
# Good old OLS'en won't always save you!
#
# Can you think of example where linear models won't work?

# %% [markdown]
# - human communication data, e.g. visual (text, symbol) and oral (speech, music).
# - networks of social relations and other activities
# - temporal-spatial data, e.g. satelite, micro address, neighborhood (street-view)

# %% [markdown]
# ## Limits to linear models
#
# Example: Hand-writing, including digits, used to be difficult to map to integers
# - What does data look like? Image 28x28 pixels in grayscale color
# - Corresponds to almost 1,000 variables/features!
#
# <center><img src='../base/fig/mnist/digits.png' alt="Drawing" style="width: 420px;"/></center>

# %% [markdown]
# # The fundamental modeling problem

# %% [markdown]
# ## A flexible model
# *What is a polynomial regression?*
#
# - Fitting a curve with an *n-dimenstional polynomial*
# - Can fit any "regular" curve ~ Taylor Series Approximation.

# %% [markdown]
# ## In-sample performance increases in order
# *Suppose we build models of the size of the Danish population, how do polynomial fits perform?*
# - We estimate model with data from 1769-1975.

# %%
f_pop1

# %% [markdown]
# ## Out-of-sample performance does not increase
# *Which model performs best when we extend the forecasting period from 1975 to now?*

# %%
f_pop2

# %% [markdown]
# ## Model fragility
# *What happens if we extend the prediction period until 2050? See the fifth order.*

# %%
f_pop3

# %% [markdown]
# ## The modelling dilemma

# %% [markdown]
# - **Underfitting**: Making a model that is too simple and does not capture enough patterns in data
# - **Overfitting**: Making a model with great fit on estimation data, but poor out-of-sample prediction

# %% [markdown]
# In the previous example:
# - ***underfitting***: only a intercept/constant (order 0)
# - ***overfitting***: too high order polynomial (order 5)
#
# The goal of **machine learning** is to find models that minimize these two problems simultaneously.

# %% [markdown]
# # Modelling data: overfitting vs underfitting

# %% [markdown]
# ## Model complexity (1)
# *What does a model of low complexity look like in regression problems?*

# %%
f_complexity[0]

# %% [markdown]
# ## Model complexity (2)
# *What does medium model complexity look like?*

# %%
f_complexity[1]

# %% [markdown]
# ## Model complexity (3)
# *What does high model complexity look like?*

# %%
f_complexity[2]

# %% [markdown]
# ## Model fitting
# *Quiz: Which model fitted the data best?*

# %%
f_bias_var['regression'][2]

# %% [markdown]
# # Machine learning overview

# %% [markdown]
# ## What is machine learning
# *Same same, but different*

# %% [markdown]
# - Supervised learning
#   - Models designed to infer function from input to **labeled** data.
#   - We define the `target` as labels in data we wish to model.
#       - Example: population as a function of year.
#       - In other words: do we have an outcome, $y$, to model?
# - Unsupervised learning
#   - Find patterns and relationships from **unlabeled** data.
#   - This may involve clustering, dimensionality reduction and more.

# %% [markdown]
# ## Machine learning  for us
# *How might this be useful for economist?*
#
# Think about use cases for half a minute.

# %% [markdown]
# ## ML for economics (1): improving econometrics
#
# Many econometric methods try to establish causality:
#
# - applications for
#     - linear models with many covariates
#     - instrument variables (IV)
#     - matching
# - intuition: models for matching, IV have an inherent prediction problem:
#     - e.g. first stage in IV, propensity score in matching
#     - can be enhanced with machine learning
# - can be used in applied work either quasi-experimental or structural estimation

# %% [markdown]
# ## ML for economics (2): testing predictive power
#
# ML helps us with making predictive models:
#
# - Optimize predictive performance of model
# - Assess the performance of our models
#
# Can we use ML to help us clarify whether a new set of variables improve our model?
#
# - (covered later in course)

# %% [markdown]
# ## ML for economics (3a): better policy targetting
#
# Social and medical scientists are often involved in policies aimed at:
# - alleviating poverty, decrease drop-out, crime etc.
#
# Efficacy of these programs requires targetting of individuals:
# - who is most poor, who is most at risk of dropping out? dying?
#
# Kleinberg et al. 2015 show that mortality from surgery can be predicted in advance.
# - save billions of $ and not cause pain of surgery
# - if causal effects of intervention are small

# %% [markdown]
# ## ML for economics (3b): better policy targetting
# Another examples of prediction policy of health:
# - [Hastings et al. (2020)](https://doi.org/10.1073/pnas.1905355117) examines whether we should prescribe opioids to you (what is your risk of addiction?)
#
# <center><img src='Hastings_et_al_2020_Fig2.PNG' alt="Drawing" style="width: 800px;"/></center>
#
#
# Additional examples prediction  policies
# - should we audit your firm for VAT and tax review (how much do we predict you cheat)
# - should we admit you to this education? (what is your dropout risk)

# %% [markdown]
# ## ML for economics (4): new data
#
# Machine learning can help us *'fill in the blanks'* and impute missing data
#
# Input: Google Street View (360° images)
# - Infer latent variables in neighborhood:
#   - safety ([Naik, Raskar & Hidalgo, 2016](https://doi.org/10.1257/aer.p20161030)) and 2)
#   - sociodemography ([Gebru et al. 2017](https://doi.org/10.1073/pnas.1700035114); [Nikhil et al. 2017](https://doi.org/10.1073/pnas.1619003114))
#
# Input: Cell phone data
# - Inferring poverty. ([Blumenstock, Cadamuro, On 2015](https://doi.org/10.1126/science.aac4420 ))
# - Inferring mode of transportation. ([Bjerre-Nielsen et al., 2020](https://doi.org/10.1371/journal.pone.0234003))
#
# Facebook data (likes, way of writing, town) can help infer
# - personality and demographics ([e.g. the Cambridge Analytica scandal](https://www.nytimes.com/2018/04/04/us/politics/cambridge-analytica-scandal-fallout.html)); socioeconomic status; current mood

# %% [markdown]
# ## ML for economics (5): decision problems and game theory
#
# We can solve decision problems and games using reinforcement learning
# - uses neural networks to teach "agent" to play game
#     - learn to play computer games, poker, etc.
# - solve problems where game theory is intractable
#     - e.g. investigate pricing dynamics when using algorithms ([Calvano et al. 2020](https://doi.org/10.1257/aer.20190623))

# %% [markdown]
# ## Beware!
#
# Applying predictive algorithms can have adverse consequences
#     - If subsequent interventions have causal effects
#
# O'Neil warns in her book "[Weapons of Math Destruction](https://www.goodreads.com/book/show/28186015-weapons-of-math-destruction)" that algorithms may be biased
#   - Models that predict recidivism biased for ethnic minorities
#     - Minorities likely to serve longer jail sentences when used!
#   - [Buolamwini and Gebru (2018)](http://proceedings.mlr.press/v81/buolamwini18a.html): face recognition more erroneous for female and ethnic minorities
#     - Why? Because it has been fed pictures of mostly white male
#
# NOTE: we cover this later in course

# %% [markdown]
# # Supervised machine learning

# %% [markdown]
# ## Supervised machine learning (ML) problems
# *How can we categorize a supervised ML model?*

# %% [markdown]
# Suppose we have model $y=x^T\beta$
#
# We distinguish by type of the `target` variable `y`:
# - **regression**: predict a numeric value
# - **classification**: distinguish between target categories (non-numeric data)

# %% [markdown]
# ## Supervised ML problems (2)
# *Which one is classification, which one is regression?*

# %%
f_identify_question

# %% [markdown]
# ## Supervised ML problems (3)

# %%
f_identify_answer

# %% [markdown]
# ## Regression models
# *What are examples of regressions models?*
#
# - Example of targets: income, life expectancy, education length (years)

# %% [markdown]
# *What is the underlying data of the target, $y$?*

# %% [markdown]
# - target is `continuous`

# %% [markdown]
# ## Classification models
# *What are examples of classification models?*

# %% [markdown]
# Target, `y`, are categories
# - Examples of target: kind of education (linguistics, math), mode of transportation
#     - sometimes known as `factor` in statistics

# %% [markdown]
# ## Example of supervised ML
# *Classification or regression?*
#
# We load the titanic data. We select variables and make dummy variables from categorical. We split into target and features.
#
# Target is: ...?

# %%
import numpy as np
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset('titanic')
cols = ['survived','class', 'sex', 'sibsp', 'age', 'alone']
titanic_sub = pd.get_dummies(titanic[cols].dropna(), drop_first=True).astype(np.int64)  

X = titanic_sub.drop('survived', axis=1)
y = titanic_sub.survived

# %% [markdown]
# ## Definitions
#
# ML lingo and econometric equivalents (in italic)
#
# - `feature` vector, $\textbf{x}_i$, i.e a row of input variables
#   - = explanatory *variables* in econometrics
# - `weight` vector, $\textbf{w}$, i.e model parameters
#   - = *coefficients* in econometrics where denoted $\beta$
# - `bias` term, $w_0$, i.e. the model intercept
#   - = the *constant* variable in denoted $\beta_0$

# %% [markdown]
# # The perceptron model

# %% [markdown]
# ## Inspiration for articifial neuron
#
# A real neuron maps stimulus (input) to output.
#
# [Research estimates](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5063692) there are 55–70 billion neurons in the brain.
# <center><img src='https://github.com/rasbt/python-machine-learning-book-2nd-edition/raw/master/code/ch02/images/02_01.png' alt="Drawing" style="width: 900px;"/></center>
#
# (Image from [Raschka, 2017](https://github.com/rasbt/python-machine-learning-book-2nd-edition))

# %% [markdown]
# ## Model archicture
# We are interested in making a decision rule that takes arbitrary input and outputs either positive or negative.

# %% [markdown]
# Mathematically we define this map as $\phi: \mathbb{R}^p\rightarrow\{-1, 1\}$.
#
# \begin{align}
# \phi(z_i)=\begin{cases}
# \hfill1, & z_i>0\\
# -1, & z_i\le0
# \end{cases}
# \end{align}
#
# - `net-input`, $z_i = \underset{~vector\,form}{\underbrace{\boldsymbol{w}^{T}\boldsymbol{x}_i}} = \underset{~expanded\,form}{\underbrace{1\cdot w_0+w_1x_{i,1}+...+w_kx_{i,k}}}$
#
# - `unit step function`, $\phi$, checks if value exceeds threshold

# %% [markdown]
# ## Visualizing the decision boundary
# *The unit step function (left) and the decision boundary (right)*
#
# <center><img src='https://github.com/rasbt/python-machine-learning-book-2nd-edition/raw/master/code/ch02/images/02_02.png' alt="Drawing" style="width: 1000px;"/></center>
#
#
# (Image from [Raschka, 2017](https://github.com/rasbt/python-machine-learning-book-2nd-edition))

# %% [markdown]
# ## A good model?
# *When does the articial neuron work?*

# %% [markdown]
# If the two target types are linearly separable:
#
# <center><img src='https://github.com/rasbt/python-machine-learning-book-2nd-edition/raw/master/code/ch02/images/02_03.png' alt="Drawing" style="width: 1200px;"/></center>
#
# (Image from [Raschka, 2017](https://github.com/rasbt/python-machine-learning-book-2nd-edition))

# %% [markdown]
# ## Computing model weights
# *How do we estimate the model parameters?*

# %% [markdown]
# Step 1. initialize the weights,  $\hat{w}$, with small random numbers
#
# Step 2. for each (training) observation, i=1, .., n
#   1. compute predicted target, $\hat{y}_i$
#   1. update weights $\hat{w}$ based on perceptron rule (explanation follows)

# %% [markdown]
# ## Predicted target
# *How do we compute the predicted target $\hat{y}$?*

# %% [markdown]
# We apply a transformation on the net-input :
# - single observation, expanded notation:
# \begin{align*}
# \hat{y}_i= \phi(z_i),\quad z_i=w_0+w_1x_{i,1}+...+w_kx_{i,k}
# \end{align*}

# %% [markdown]
# - single observation, vector notation:
# \begin{align*}
# \hat{y}_i= \phi(z_i),\quad z_i=\boldsymbol{w}^{T}\boldsymbol{x}_i
# \end{align*}

# %% [markdown]
# - multiple observations, matrix notation:
# \begin{align*}
# \hat{\boldsymbol{y}}= & \phi(\boldsymbol{z}),\quad\boldsymbol{z}=\boldsymbol{X}\boldsymbol{w}
# \end{align*}

# %% [markdown]
# ## The perceptron learning rule
# *How do we update weights?*

# %% [markdown]
# Weights are updated as follows with one observation:
# \begin{align*}
# w_i&=w_i+\Delta w_i\\
# \Delta w_i&=\eta\cdot(y_i-\phi(z_i))\cdot \textbf{x}_{i}\end{align*}
#
# where $\eta$ is the learning rate

# %% [markdown]
# If multiple observations we can use vector notation:
# \begin{align*}
# w&=w+\Delta w\\
# \Delta w&=\eta\cdot (y-\phi(z))^T X\end{align*}

# %% [markdown]
# ## Overview of perceptron learning rule
#
# The computation process

# %% [markdown]
# <center><img src='https://github.com/rasbt/python-machine-learning-book-2nd-edition/raw/master/code/ch02/images/02_04.png' alt="Drawing" style="width: 1000px;"/></center>
#
# (Image from [Raschka, 2017](https://github.com/rasbt/python-machine-learning-book-2nd-edition))

# %% [markdown]
# ## Implementation in Python (1)
# *Let's set some values of input and output*

# %%
X = np.random.normal(size=(3, 2)) # feature matrix
y = np.array([1, -1, 1]) # target vector
w = np.random.normal(size=(3)) # weight vector
print('X:\n',X)
print('y:',y)
print('w:',w)
# Out:
# X:
#  [[-0.80465974  2.47641856]
#  [-0.24547838 -0.35616132]
#  [-0.18317626  0.88008699]]
# y: [ 1 -1  1]
# w: [-0.19813352  0.01438546 -0.56355087]

# %% [markdown]
# ## Implementation in Python (2)
# *How do we compute the errors vectorized?*

# %%
# compute net-input 
z = w[0] + X.dot(w[1:]) # (w[0]: bias, w[1:]: other weights, X: features)

# unit step-function
positive = z>0 # compute prediction (boolean)
y_hat = np.where(positive, 1, -1)  # convert prediction

# compute errors
e = y - y_hat # compute errors

# %% [markdown]
# ## Implementation in Python (3)
# *How do we compute the updated weights?*

# %%
# learning rate
eta = 0.001 

# update weights 
update_vars = eta*X.T.dot(e) 
update_bias = eta*e.sum()/2

# %% [markdown]
# ## Working with the perceptron (1)
# We load the iris data.

# %%
iris = sns.load_dataset('iris').iloc[:100] # drop virginica
sns.scatterplot(x=iris.sepal_length, y=iris.petal_length, hue=iris.species)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# set features and target

X = iris.iloc[:, [0, 2]].values # keep only petal_length and sepal_length
y = np.where(iris.species=='setosa', 1, -1) # convert to 1 for setosa, -1 for versicolor

# %% [markdown]
# ## Working with the perceptron (2)
# *How do we fit the perceptron model?* (load perceptron code [here](#Code-from-Raschka-2017)).

# %%
# initialize the perceptron 
clf = Perceptron(n_iter=10) 
# clf: short for classifier (classification model), 
# n_iter: number of times to run through all observations

# fit the perceptron (estimate the model)
# runs 10 iterations of updating the model
clf.fit(X,y)

# %% [markdown]
# ## Working with the perceptron (3)
# *How can we evaluate the model??*

# %%
print('Number of errors: %i' % sum(clf.predict(X)!=y))

# we plot the decisions
plot_decision_regions(X,y,clf)
# Out:
# Number of errors: 0

# %% [markdown]
# ## Working with the perceptron (4)
# *How does the model performance change??*

# %%
f,ax = plt.subplots(figsize=(12, 4))
ax.set_xticks(range(11))
ax.plot(range(1, len(clf.errors_) + 1), clf.errors_, marker='o')
ax.set_xlabel('Number of iterations')
ax.set_ylabel('Number of errors')
# Out:
# Text(0, 0.5, 'Number of errors')

# %% [markdown]
# # Simple model validation

# %% [markdown]
# ## Model validation
# *How can we see how our model generalizes?*

# %% [markdown]
# We can simulate out-of-sample prediction. How?

# %% [markdown]
# - Idea: Use some of our sample for model evaluation.
# - Implementation - divide data randomly into two subsets:
#     - `training data` for estimation;
#     - `test data` for evaluation.
# - Note: does not work for time series.

# %% [markdown]
# ## Random partitioning
# We revert to titanic, `y`: survived, `X`: everything else

# %%
print(titanic_sub.head(3))
X = titanic_sub.drop('survived', axis=1).values
y = titanic_sub.survived.replace(0,-1).values
# Out:
#    survived  sibsp  age  alone  class_Second  class_Third  sex_male
# 0         0      1   22      0             0            1         1
# 1         1      1   38      0             0            0         0
# 2         1      0   26      1             0            1         0

# %% [markdown]
# We split the data into test and training samples

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5, random_state=0)

# %% [markdown]
# ## The value of training
# We revert to titanic, `y`: survived, `X`: everything else

# %%
for n in [1,10,100, 1000]:
    clf2 = Perceptron(n_iter=10) 
    clf2.fit(X_train, y_train)
    acc = np.mean(y_test-clf2.predict(X_test)==0)
    print(n, acc)
# Out:
# 1 0.4173669467787115
# 10 0.4173669467787115
# 100 0.4173669467787115
# 1000 0.4173669467787115

# %% [markdown]
# # Beyond the perceptron

# %% [markdown]
# ## Motivation
# *What might we change about the perceptron?*

# %% [markdown]
# 1. Change from updating errors that are binary to continuous
# 2. Use more than one observation a time for updating

# %% [markdown]
# ## The activation function (1)
# *What else might we use to update errors?*

# %% [markdown]
# - The most simple is **no transformation** of the net-input, i.e. $\phi(z_i)=z_i$.
#
# - When we change this from perceptron we call it Adaptive Linear Neuron (**Adaline**).

# %% [markdown]
# ## The activation function (2)
# *How is this different from the Perceptron?*

# %% [markdown]
# <center><img src='https://github.com/rasbt/python-machine-learning-book-2nd-edition/raw/master/code/ch02/images/02_09.png' alt="Drawing" style="width: 800px;"/></center>
#
# (Image from [Raschka, 2017](https://github.com/rasbt/python-machine-learning-book-2nd-edition))

# %% [markdown]
# ## The activation function (3)
# *Which activation functions can be used?*

# %% [markdown]
# - Linear
# - Logistic (Sigmoid)
# - Unit step, sign

# %% [markdown]
# See page 450 in Python for Machine Learning.

# %% [markdown]
# ## The activation function (4)
# *How do Adaline and Logistic regression differ?*

# %% [markdown]
# <center><img src='https://github.com/rasbt/python-machine-learning-book-2nd-edition/raw/master/code/ch03/images/03_03.png' alt="Drawing" style="width: 800px;"/></center>
#
# (Image from [Raschka, 2017](https://github.com/rasbt/python-machine-learning-book-2nd-edition))

# %% [markdown]
# ## A new objective (1)
# *The update rule in perceptron seems ad hoc, is Adaline more general?*

# %% [markdown]
# - Yes, we minimize the sum of squared errors (SSE). The SSE for Adaline is:
# \begin{align}SSE&=\boldsymbol{e}^{T}\boldsymbol{e}=e_1^2+..+e_n^2\\\boldsymbol{e}&=\textbf{y}-\textbf{X}\textbf{w}\end{align}

# %% [markdown]
# *Doesn't the above look strangely familiar?*

# %% [markdown]
# - Yes, it is the same objective as OLS. The difference:
#     - OLS computes the exact solution
#         - using system of equations from first order conditions.
#     - We make an approximate solution.

# %% [markdown]
# ## A new objective (2)
# *How do we make the approximate solution?*

# %% [markdown]
# - Two general classes:
#   -  We approximate the first order derivative ~ gradient descent (GD)
#   -  We approximate both first and second order derivative ~ quasi Newton
#  <br />
# - We take gradient descent
#    - much simpler and available for more models
#    - one disadvantage is that it is slower

# %% [markdown]
# ## A new objective (3)
# *How does a gradient descent look?*

# %% [markdown]
# An algorithm that finds the direction where expected differences are largest. Attempt of satisfying first order condition (FOC).
#
# <center><img src='https://upload.wikimedia.org/wikipedia/commons/7/79/Gradient_descent.png' alt="Drawing" style="width: 400px;"/></center>
#
# (Image produced by [Zerodamage](https://commons.wikimedia.org/wiki/User:Zerodamage))

# %% [markdown]
# ## A new objective (4)
# *What is the first order derivative of SSE wrt. weights in Adaline?*

# %% [markdown]
# \begin{align}\frac{\partial SSE}{\partial w}=\textbf{X}^T\textbf{e},\end{align}

# %% [markdown]
# *How do we update with GD in Adaline?*

# %% [markdown]
#   - Idea: take small steps to approximate the solution.
#
#   - $\Delta w=-\eta\textbf{X}^T\textbf{e}=-\eta\cdot\textbf{X}^T(\textbf{y}-\hat{\textbf{y}})$

# %% [markdown]
# ## A new objective (5)
# The gradient descent algorithm we just learned uses the whole data.
#
# - Often known as batch gradient descent.
#
# *What might be a smart way of changing (batch) gradient descent?*

# %% [markdown]
# - We only use a subset of the data. Two variants:
#     - *stochastic gradient descent* (SGD): uses random subset of observations
#     - *mini batch*: uses deterministic subset of observations (loop whole dataset)
#
# - Idea: we converge faster by computing update for subset of data
#     - Note: we may need a million repetitions.

# %% [markdown]
# # Linear regression models

# %% [markdown]
# ## Estimation
# *Do we know already some ways to estimate regression models?*

# %% [markdown]
# - Social scientists know all about the Ordinary Least Squares (OLS).
#   - $\beta=(\textbf{X}^T\textbf{X})^{-1}\textbf{X}^T\textbf{y}$
#
# - Some properties of OLS
#   - Exact solution from first order conditions
#   - Estimates both parameters and their standard deviation.
#   - Is the best linear unbiased estimator under regularity conditions.
#   - Computation requires non perfect multicollinarity.

# %% [markdown]
# ## Estimation
# *What are the ways we can estimate a linear regression model?*

# %% [markdown]
# - first order methods (e.g. gradient descent)
# - second order methods (Newton, quasi-Newton)
#     - often faster, but may not always work
#     - used e.g. for logistic regression
# - what about local minima?
#     - we should make grid search over random values

# %% [markdown]
# ## Gradient descent
# *Can you explain gradient descent in details?*

# %% [markdown]
# - Yes, like with Adaline, we minimize the sum of squared errors (SSE):
# \begin{align}SSE&=\boldsymbol{e}^{T}\boldsymbol{e}\\\boldsymbol{e}&=\textbf{y}-\textbf{X}\textbf{w}\end{align}

# %%
X = np.random.normal(size=(3,2))
y = np.random.normal(size=(3))
w = np.random.normal(size=(3))

e = y-(w[0]+X.dot(w[1:]))
SSE = e.T.dot(e)

# %% [markdown]
# ## Gradient descent
# *And what about the updating..? What is it about the first order deritative?*

# %% [markdown]
# \begin{align}
# \frac{\partial SSE}{\partial\hat{\textbf{w}}}&=\textbf{X}^T\textbf{e}\qquad\text{(the gradient)}\\
#  \Delta\hat{\textbf{w}}&=-\eta\cdot\textbf{X}^T\textbf{e}\qquad\text{(gradient descent)}\\
#  &=-\eta\cdot\textbf{X}^T(\textbf{y}-\hat{\textbf{y}})\\
#  &=-\eta\cdot\textbf{X}^T(\textbf{y}-\textbf{X}\hat{\textbf{w}})
# \end{align}

# %%
eta = 0.001 # learning rate
fod = X.T.dot(e)
update_vars = eta*fod
update_bias = eta*e.sum()

# %% [markdown]
# ## Exact vs. approximate
# Exact solution / OLS
# - Only works on linear models
# - Quadratic scaling in number of variables ($K$) is slow!
#     - Computation complexity $\mathcal{O}(K^2N)$  ([read more](https://math.stackexchange.com/questions/84495/computational-complexity-of-least-square-regression-operation))
#
# Approximate methods / gradient descent
#   - Works despite high multicollinarity
#   - Scales well: can be applied in subsets to very large datasets
#     - We only need subset in memory
#     - Note: not guaranteed convergence time!
#   - Works on non-linear problems, e.g. neural networks.

# %% [markdown]
# # The end
# [Return to agenda](#Agenda)

# %% [markdown]
# # Code for plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import seaborn as sns

plt.style.use('ggplot')
# %matplotlib inline

SMALL_SIZE = 14
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.rcParams['figure.figsize'] = 12, 5 # set default size of plots

# %% [markdown]
# ### Population plots

# %%
# %run pop_plots.ipynb

# %% [markdown]
# ### Plots of ML types

# %%
# %run ../base/ML_plots.ipynb

# %% [markdown]
# ### Code from Raschka 2017

# %%
import requests
import os
base_url = 'https://raw.githubusercontent.com/rasbt/python-machine-learning-book-2nd-edition/master/code/ch02/'

for filename in ('ch02.py', 'iris.data', 'iris.names.txt'):
    if not os.path.exists(filename):
        response = requests.get(base_url+filename)
        with open(filename,'wb') as f:
            f.write(response.text.encode('utf-8'))
    
from ch02 import Perceptron, AdalineGD, AdalineSGD, plot_decision_regions
